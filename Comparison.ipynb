# %%
# 1. Import Packages/Modules

import cimcb as cb
from beakerx.object import beakerx
beakerx.pandas_display_table() # by default display pandas tables as BeakerX interactive tables

# %%
# 2. Locate xlsx files

methods = ['pls_eval', 'pcr_eval', 'pclr_eval', 'rf_eval', 'svm_eval', 'rbfnn_eval', 'nnlinlin_eval', 'nnlinlog_eval', 'nnloglog_eval']

# %%
# 3. Table

train = cb.utils.load_comparisonXL(methods)
display(train)
