# %%
# 1. Import Packages/Modules

import cimcb as cb
from beakerx.object import beakerx
beakerx.pandas_display_table() # by default display pandas tables as BeakerX interactive tables
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files

methods = ['MTBLS90_pls_eval',
           'MTBLS90_pcr_eval',
           'MTBLS90_pclr_eval',
           'MTBLS90_rf_eval',
           'MTBLS90_svm_eval',
           'MTBLS90_nnlinlin_eval',
           'MTBLS90_nnlinlog_eval',
           'MTBLS90_nnloglog_eval']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(methods, 'train')
display(train)

# %%
# 4. Train Table

train = cb.utils.load_comparisonXL(methods, 'test')
display(train)
